# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# Exercise 1

# %% [markdown]
# (a).

# %%
#reading the data 
data_frame = pd.read_csv("train.csv")
data_frame.head()
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   4         88.944468             57.862692
# 1                   5         92.729214             58.518416
# 2                   4         88.944468             57.885242
# 3                   4         88.944468             57.873967
# 4                   4         88.944468             57.840143
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          66.361592              36.116612             1.181795
# 1          73.132787              36.396602             1.449309
# 2          66.361592              36.122509             1.181795
# 3          66.361592              36.119560             1.181795
# 4          66.361592              36.110716             1.181795
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 1.062396          122.90607              31.794921
# ...

# %%
Train_Val,Test= train_test_split(data_frame, test_size = 0.2)

# %% [markdown]
# (b).

# %%
Train, Validation = train_test_split(Train_Val, test_size = 0.25)
#Train.shape
#Validation.shape

# %% [markdown]
# Exercise 2

# %% [markdown]
# (a).

# %%
lambda_1 = [0, 10 ** -6, 10 ** -5, 10 ** -4, 10 ** -3, 10 ** -2, 10 ** -1, 1]
lambda_2 = [0, 10 ** -6, 10 ** -5, 10 ** -4, 10 ** -3, 10 ** -2, 10 ** -1, 1]
param = pd.DataFrame(columns=['lambda_1','lambda_2','alpha','l1_ratio'])
for i in lambda_1:
  for d in lambda_2:
    alpha, l1_ratio = cal_lambdas(i,d)
    temp = {'lambda_1': i, 'lambda_2': d, 'alpha': alpha, 'l1_ratio': l1_ratio} 
    param = param.append(temp, ignore_index=True)

def cal_lambdas(L1,L2):
  alpha = L1+L2
  if L1 == 0 and L2 == 0:
    l1_ratio = 0
  else:
    l1_ratio = L1/(L1+L2)
  return(alpha, l1_ratio)

#param

# %% [markdown]
# (b,c,d).

# %%
Train_X = Train.iloc[:, 0:81]
Train_Y = Train.iloc[:, 81]
Validation_X = Validation.iloc[:,0:81]
Validation_Y = Validation.iloc[:,81]
Result_Train = {}
Result_Valid = {}

for l1 in lambda_1:
  for l2 in lambda_2:
    alpha, l1_ratio = cal_lambdas(l1,l2)
    elastic = ElasticNet(alpha, l1_ratio)
    ml_fit = elastic.fit(Train_X,Train_Y)
    
    train_res = ml_fit.predict(Train_X)
    train_MSE = mean_squared_error(train_res, Train_Y)
    Result_Train[(l1,l2)] = train_MSE
    
    valid_res = ml_fit.predict(Validation_X)
    valid_MSE = mean_squared_error(valid_res, Validation_Y)
    Result_Valid[(l1,l2)] = valid_MSE
# Out:
# C:\Users\Reza\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass l1_ratio=0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# <ipython-input-100-4f7ae5a7583f>:14: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   ml_fit = elastic.fit(Train_X,Train_Y)
# C:\Users\Reza\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Reza\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1969800.6648319592, tolerance: 1490.739728024836
# ...

# %%
result = pd.DataFrame(columns=['lambda_1','lambda_2','MSE_Train','MSE_Validation'])
for i in lambda_1:
  for d in lambda_2:
    alpha, l1_ratio = cal_lambdas(i,d)
    temp = {'lambda_1': i, 'lambda_2': d, 'MSE_Train': Result_Train[i,d], 'MSE_Validation': Result_Valid[i,d]} 
    result = result.append(temp, ignore_index=True)

pd.set_option('display.max_rows', result.shape[0]+1)
#result
result.to_csv(r'C:\Users\Reza\Desktop\result.csv', index = False)

# %% [markdown]
# (e).

# %%
Train_min = min(Result_Train, key=Result_Train.get)
Valid_min = min(Result_Valid, key=Result_Valid.get)
Result_Train_min= Result_Train[Train_min]
Result_Valid_min= Result_Valid[Valid_min]
print("Train data:         lambda1= " + str(Train_min[0]) + " ,  lambda2= "  + str(Train_min[1]) + "   with the MSE:  " + str(Result_Train_min))
print("Validation data:    lambda1= " + str(Valid_min[0]) + " ,  lambda2= "  + str(Valid_min[1]) + "   with the MSE:  "  + str(Result_Valid_min))
# Out:
# Train data:         lambda1= 0 ,  lambda2= 0.0001   with the MSE:  308.77948803580165
# Validation data:    lambda1= 0 ,  lambda2= 0.0001   with the MSE:  315.7091120517716

# %% [markdown]
# (f).

# %%
TrainVal_X = Train_Val.iloc[:,0:81]
TrainVal_Y = Train_Val.iloc[:,81]
Test_X = Test.iloc[:,0:81]
Test_Y = Test.iloc[:,81]

alpha, l1_ratio = cal_lambdas(Valid_min[0],Valid_min[1])
elastic = ElasticNet(alpha, l1_ratio)
ml_fit = elastic.fit(TrainVal_X,TrainVal_Y)


test_res = ml_fit.predict(Test_X)
test_MSE = mean_squared_error(test_res, Test_Y)


print("Test data with the MSE:  " + str(test_MSE))
# Out:
# C:\Users\Reza\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass l1_ratio=0.0 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# Test data with the MSE:  315.4272953096927
# C:\Users\Reza\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2646733.336452497, tolerance: 1998.2808943211237
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Exercise 3.

# %% [markdown]
# (a).

# %%
Mean = np.mean(Test_Y)
Errors = []
Vars = []

for i , d in enumerate(Test_Y.values):
    prediction = test_res[i]
    Error = (d-prediction)**2
    Var = (d-Mean)**2
    Errors.append(Error)
    Vars.append(Var)

TSS = np.sum(Vars)
RSS = np.sum(Errors)

R2_Statics = 1 - (RSS / TSS)
print (R2_Statics)
    

#r2_score(Test_Y, test_res)
# Out:
# 0.7298166376318247

# %% [markdown]
# (b).

# %% [markdown]
# Yes, the r-squred metric tells us how well our model fits the obsereved data. Typically a higher r-squre value is better. In other words, an r-squred value of 0.729 means that 72.9% of the data fit our regression model.
